# %%
import numpy as np
import pandas as pd 
import os

# %%
telcom=pd.read_csv('telcocustomerchurn.csv')

# %%
print(telcom.head())
# Out:
#    Unnamed: 0_demographics Customer ID  Count_demographics  Gender  Age  \
# 0                     4006  0002-ORFBO                   1  Female   37
# 1                     4788  0003-MKNFE                   1    Male   46
# 2                     1901  0004-TLHLJ                   1    Male   50
# 3                      395  0011-IGKFF                   1    Male   78
# 4                      368  0013-EXCHZ                   1  Female   75
#
#   Under 30 Senior Citizen Married Dependents  Number of Dependents  ...  \
# 0       No             No     Yes         No                     0  ...
# 1       No             No      No         No                     0  ...
# 2       No             No      No         No                     0  ...
# 3       No            Yes     Yes         No                     0  ...
# 4       No            Yes     Yes         No                     0  ...
#
#    Device Protection Tech Support  Streaming TV_customerc  \
# 0                 No          Yes                     Yes
# 1                 No           No                      No
# 2                Yes           No                      No
# 3                Yes           No                     Yes
# 4                 No          Yes                     Yes
#
#   Streaming Movies_customerc Contract_customerc Paperless Billing_customerc  \
# 0                         No           One year                         Yes
# 1                        Yes     Month-to-month                          No
# 2                         No     Month-to-month                         Yes
# 3                        Yes     Month-to-month                         Yes
# 4                         No     Month-to-month                         Yes
#
#    Payment Method_customerc Monthly Charges  Total Charges_customerc  Churn
# 0              Mailed check            65.6                    593.3     No
# 1              Mailed check            59.9                    542.4     No
# 2          Electronic check            73.9                   280.85    Yes
# 3          Electronic check            98.0                  1237.85    Yes
# 4              Mailed check            83.9                    267.4    Yes
#
# [5 rows x 84 columns]

# %%
telcom.shape
# Out:
# (7043, 84)

# %%
telcom.describe()
# Out:
#        Unnamed: 0_demographics  Count_demographics          Age  \
# count              7043.000000              7043.0  7043.000000
# mean               3521.000000                 1.0    46.509726
# std                2033.283305                 0.0    16.750352
# min                   0.000000                 1.0    19.000000
# 25%                1760.500000                 1.0    32.000000
# 50%                3521.000000                 1.0    46.000000
# 75%                5281.500000                 1.0    60.000000
# max                7042.000000                 1.0    80.000000
#
#        Number of Dependents  Unnamed: 0_location  Count_location  \
# count           7043.000000          7043.000000          7043.0
# mean               0.468692          3521.000000             1.0
# std                0.962802          2033.283305             0.0
# min                0.000000             0.000000             1.0
# 25%                0.000000          1760.500000             1.0
# 50%                0.000000          3521.000000             1.0
# 75%                0.000000          5281.500000             1.0
# max                9.000000          7042.000000             1.0
#
#            Zip Code     Latitude    Longitude   Unnamed: 0  ...  \
# count   7043.000000  7043.000000  7043.000000  7043.000000  ...
# mean   93486.071134    36.197455  -119.756684  3521.000000  ...
# std     1856.768045     2.468929     2.154425  2033.283305  ...
# min    90001.000000    32.555828  -124.301372     0.000000  ...
# 25%    92101.000000    33.990646  -121.788090  1760.500000  ...
# 50%    93518.000000    36.205465  -119.595293  3521.000000  ...
# 75%    95329.000000    38.161321  -117.969795  5281.500000  ...
# max    96150.000000    41.962127  -114.192901  7042.000000  ...
#
#        Unnamed: 0_status  Count_status  Satisfaction Score  Churn Value  \
# count        7043.000000        7043.0         7043.000000  7043.000000
# mean         3521.000000           1.0            3.244924     0.265370
# std          2033.283305           0.0            1.201657     0.441561
# min             0.000000           1.0            1.000000     0.000000
# 25%          1760.500000           1.0            3.000000     0.000000
# 50%          3521.000000           1.0            3.000000     0.000000
# 75%          5281.500000           1.0            4.000000     1.000000
# max          7042.000000           1.0            5.000000     1.000000
#
#        Churn Score         CLTV  Unnamed: 0_customerc      LoyaltyID  \
# count  7043.000000  7043.000000           7043.000000    7043.000000
# mean     58.505040  4400.295755           3521.000000  550382.651001
# std      21.170031  1183.057152           2033.283305  260776.118690
# min       5.000000  2003.000000              0.000000  100346.000000
# 25%      40.000000  3469.000000           1760.500000  323604.500000
# 50%      61.000000  4527.000000           3521.000000  548704.000000
# 75%      75.500000  5380.500000           5281.500000  776869.000000
# max      96.000000  6500.000000           7042.000000  999912.000000
#
#             Tenure  Monthly Charges
# count  7043.000000      7043.000000
# mean     32.371149        64.761692
# std      24.559481        30.090047
# min       0.000000        18.250000
# 25%       9.000000        35.500000
# 50%      29.000000        70.350000
# 75%      55.000000        89.850000
# max      72.000000       118.750000
#
# [8 rows x 31 columns]

# %%
pd.isnull(telcom).sum()
# Out:
# Unnamed: 0_demographics        0
# Customer ID                    0
# Count_demographics             0
# Gender                         0
# Age                            0
#                               ..
# Paperless Billing_customerc    0
# Payment Method_customerc       0
# Monthly Charges                0
# Total Charges_customerc        0
# Churn                          0
# Length: 84, dtype: int64

# %%
telcom.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 84 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Unnamed: 0_demographics            7043 non-null   int64
#  1   Customer ID                        7043 non-null   object
#  2   Count_demographics                 7043 non-null   int64
#  3   Gender                             7043 non-null   object
#  4   Age                                7043 non-null   int64
#  5   Under 30                           7043 non-null   object
#  6   Senior Citizen                     7043 non-null   object
#  7   Married                            7043 non-null   object
#  8   Dependents                         7043 non-null   object
#  9   Number of Dependents               7043 non-null   int64
#  10  Unnamed: 0_location                7043 non-null   int64
#  11  Location ID                        7043 non-null   object
#  12  Count_location                     7043 non-null   int64
#  13  Country                            7043 non-null   object
#  14  State                              7043 non-null   object
#  15  City                               7043 non-null   object
#  16  Zip Code                           7043 non-null   int64
#  17  Lat Long                           7043 non-null   object
#  18  Latitude                           7043 non-null   float64
#  19  Longitude                          7043 non-null   float64
#  20  Unnamed: 0                         7043 non-null   int64
#  21  Service ID                         7043 non-null   object
#  22  Count                              7043 non-null   int64
#  23  Quarter                            7043 non-null   object
#  24  Referred a Friend                  7043 non-null   object
#  25  Number of Referrals                7043 non-null   int64
#  26  Tenure in Months                   7043 non-null   int64
#  27  Offer                              3166 non-null   object
#  28  Phone Service                      7043 non-null   object
#  29  Avg Monthly Long Distance Charges  7043 non-null   float64
#  30  Multiple Lines                     7043 non-null   object
#  31  Internet Service                   7043 non-null   object
#  32  Internet Type                      5517 non-null   object
#  33  Avg Monthly GB Download            7043 non-null   int64
#  34  Online Security                    7043 non-null   object
#  35  Online Backup                      7043 non-null   object
#  36  Device Protection Plan             7043 non-null   object
#  37  Premium Tech Support               7043 non-null   object
#  38  Streaming TV                       7043 non-null   object
#  39  Streaming Movies                   7043 non-null   object
#  40  Streaming Music                    7043 non-null   object
#  41  Unlimited Data                     7043 non-null   object
#  42  Contract                           7043 non-null   object
#  43  Paperless Billing                  7043 non-null   object
#  44  Payment Method                     7043 non-null   object
#  45  Monthly Charge                     7043 non-null   float64
#  46  Total Charges                      7043 non-null   float64
#  47  Total Refunds                      7043 non-null   float64
#  48  Total Extra Data Charges           7043 non-null   int64
#  49  Total Long Distance Charges        7043 non-null   float64
#  50  Total Revenue                      7043 non-null   float64
#  51  Unnamed: 0_status                  7043 non-null   int64
#  52  Status ID                          7043 non-null   object
#  53  Count_status                       7043 non-null   int64
#  54  Quarter_status                     7043 non-null   object
#  55  Satisfaction Score                 7043 non-null   int64
#  56  Customer Status                    7043 non-null   object
#  57  Churn Label                        7043 non-null   object
#  58  Churn Value                        7043 non-null   int64
#  59  Churn Score                        7043 non-null   int64
#  60  CLTV                               7043 non-null   int64
#  61  Churn Category                     1869 non-null   object
#  62  Churn Reason                       1869 non-null   object
#  63  Unnamed: 0_customerc               7043 non-null   int64
#  64  LoyaltyID                          7043 non-null   int64
#  65  Senior Citizen_customerc           7043 non-null   object
#  66  Partner                            7043 non-null   object
#  67  Dependents_customerc               7043 non-null   object
#  68  Tenure                             7043 non-null   int64
#  69  Phone Service_customerc            7043 non-null   object
#  70  Multiple Lines_customerc           7043 non-null   object
#  71  Internet Service_customerc         7043 non-null   object
#  72  Online Security_customerc          7043 non-null   object
#  73  Online Backup_customerc            7043 non-null   object
#  74  Device Protection                  7043 non-null   object
#  75  Tech Support                       7043 non-null   object
#  76  Streaming TV_customerc             7043 non-null   object
#  77  Streaming Movies_customerc         7043 non-null   object
#  78  Contract_customerc                 7043 non-null   object
#  79  Paperless Billing_customerc        7043 non-null   object
#  80  Payment Method_customerc           7043 non-null   object
#  81  Monthly Charges                    7043 non-null   float64
#  82  Total Charges_customerc            7043 non-null   object
#  83  Churn                              7043 non-null   object
# dtypes: float64(9), int64(22), object(53)
# memory usage: 4.5+ MB

# %%
telcom['Total Charges_customerc'] = pd.to_numeric(telcom['Total Charges_customerc'], errors='coerce')

# %%
pd.isnull(telcom["Total Charges_customerc"]).sum()
# Out:
# 11

# %%
missing=telcom.isnull().sum().reset_index().rename(columns={0:'missNum'})

# %%
missing['missRate']=missing['missNum']/telcom.shape[0]

# %%
miss_analy=missing[missing.missRate>0].sort_values(by='missRate',ascending=False)

# %%
import matplotlib.pyplot as plt
import pylab as pl

fig = plt.figure(figsize=(18,6))
plt.bar(np.arange(miss_analy.shape[0]), list(miss_analy.missRate.values), align = 'center',color=['brown','green','yellow','steelblue','red'])

plt.title('Histogram of missing value of variables')
plt.xlabel('variables names')
plt.ylabel('missing rate')
plt.xticks(np.arange(miss_analy.shape[0]),list(miss_analy['index']))
pl.xticks(rotation=90)
for x,y in enumerate(list(miss_analy.missRate.values)):
    plt.text(x,y+0.12,'{:.2%}'.format(y),ha='center',rotation=90)    
plt.ylim([0,1.2])

plt.show()

# %%
telcom['Total Charges_customerc'] = telcom['Total Charges_customerc'].fillna(telcom['Total Charges_customerc'].median())

# %%
telcom['Churn Category','Churn Reason','Offer','Internet Type'] =telcom['Churn Category','Churn Reason','Offer','Internet Type'].fillna('NA')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File D:\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('Churn Category', 'Churn Reason', 'Offer', 'Internet Type')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[55], line 1
# ----> 1 telcom['Churn Category','Churn Reason','Offer','Internet Type'] =telcom['Churn Category','Churn Reason','Offer','Internet Type'].fillna('NA')
#
# File D:\anaconda3\Lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File D:\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: ('Churn Category', 'Churn Reason', 'Offer', 'Internet Type')
